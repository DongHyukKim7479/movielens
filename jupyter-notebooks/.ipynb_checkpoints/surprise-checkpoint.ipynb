# %% [markdown]
# # Surprise for Collaborative Filtering
# ## 1. User-User CF (KNNWithMeans)
# ## 2. Item-Item CF (KNNWithMeans)
# ## 3-1. Matrix Factorization (SVD - HyperParameter Tuning with GridSearchCV)
# ## 3-2. Matrix Factorization (SVD - HyperParameter Tuning with RandomizedSearchCV)
# ### reference: https://kerpanic.wordpress.com/2018/03/26/a-gentle-guide-to-recommender-systems-with-surprise/

# %%
file_path = '/Users/morulabs/dev/source/git_hub/recsys/data/ml-latest-small/ratings.csv'

# %% [markdown]
# ## 1. User-User CF (KNNWithMeans)

# %%
from surprise import KNNWithMeans, Dataset, accuracy
from surprise.model_selection import train_test_split
from surprise.reader import Reader

reader = Reader(line_format='user item rating timestamp', sep=',')
data = Dataset.load_from_file(file_path, reader=reader)

train_set, test_set = train_test_split(data, test_size=0.2)

algo_user = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
algo_user.fit(train_set)


uid = str(196)
for movie_id in range(1, 11):
    iid = str(movie_id)
    pred = algo_user.predict(uid, iid, r_ui=4, verbose=True)

test_pred = algo_user.test(test_set)

# get RMSE
print('User-based Model: Test set')
accuracy.rmse(test_pred, verbose=True)

# evaluate on the trianset
print('User-based Model: Training Set')
train_pred = algo_user.test(train_set.build_testset())
accuracy.rmse(train_pred)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/reader.py in parse_line(self, line)
#      93                 uid, iid, r, timestamp = (line[i].strip()
# ---> 94                                           for i in self.indexes)
#      95             else:
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/reader.py in <genexpr>(.0)
#      93                 uid, iid, r, timestamp = (line[i].strip()
# ---> 94                                           for i in self.indexes)
#      95             else:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ef1d17a6e95b> in <module>()
#       4
#       5 reader = Reader(line_format='user item rating timestamp', sep='\t')
# ----> 6 data = Dataset.load_from_file(file_path, reader=reader)
#       7
#       8 train_set, test_set = train_test_split(data, test_size=0.2)
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/dataset.py in load_from_file(cls, file_path, reader)
#     120         """
#     121
# --> 122         return DatasetAutoFolds(ratings_file=file_path, reader=reader)
#     123
#     124     @classmethod
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/dataset.py in __init__(self, ratings_file, reader, df)
#     283         if ratings_file is not None:
#     284             self.ratings_file = ratings_file
# --> 285             self.raw_ratings = self.read_ratings(self.ratings_file)
#     286         elif df is not None:
#     287             self.df = df
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/dataset.py in read_ratings(self, file_name)
#     172         with open(os.path.expanduser(file_name)) as f:
#     173             raw_ratings = [self.reader.parse_line(line) for line in
# --> 174                            itertools.islice(f, self.reader.skip_lines, None)]
#     175         return raw_ratings
#     176
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/dataset.py in <listcomp>(.0)
#     171
#     172         with open(os.path.expanduser(file_name)) as f:
# --> 173             raw_ratings = [self.reader.parse_line(line) for line in
#     174                            itertools.islice(f, self.reader.skip_lines, None)]
#     175         return raw_ratings
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/reader.py in parse_line(self, line)
#      99
#     100         except IndexError:
# --> 101             raise ValueError('Impossible to parse line. Check the line_format'
#     102                              ' and sep parameters.')
#     103
#
# ValueError: Impossible to parse line. Check the line_format and sep parameters.

# %% [markdown]
# ## 2. KNNWithMeans (Item-Item CF)

# %%
from surprise import KNNWithMeans, Dataset, accuracy
from surprise.model_selection import train_test_split
from surprise.reader import Reader

reader = Reader(line_format='user item rating timestamp', sep='\t')
data = Dataset.load_from_file(file_path, reader=reader)
train_set, test_set = train_test_split(data, test_size=0.2)

algo_item = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo_item.fit(train_set)

test_pred = algo_item.test(test_set)

print('Item-based Model: Test Set')
accuracy.rmse(test_pred, verbose=True)

print('Item-based Model: Training Set')
train_pred = algo_item.test(train_set.build_testset())
accuracy.rmse(train_pred)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Item-based Model: Test Set
# RMSE: 0.9182
# Item-based Model: Training Set
# RMSE: 0.4380
# 0.4379996865385731

# %% [markdown]
# ## 3-1. Matrix Factorization (SVD - HyperParameter Tuning with GridSearchCV)
# ### GridSearchCV.fit 실행시 싱글코어로 도는 현상. 시간이 오래 걸림

# %%
from surprise import SVDpp, SVD, Dataset, accuracy
from surprise.model_selection import train_test_split, GridSearchCV, cross_validate
from surprise.reader import Reader

reader = Reader(line_format='user item rating timestamp', sep='\t')
data = Dataset.load_from_file(file_path, reader=reader)
train_set, test_set = train_test_split(data, test_size=0.2)

param_grid = {'n_factors': [110, 120, 140, 160], 'n_epochs': [90, 100, 110], 
              'lr_all': [0.001, 0.003], 'lr_all': [0.001, 0.003, 0.005, 0.008],
              'reg_all': [0.08, 0.1, 0.15]}

gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=5)
gs.fit(data)

algo_grid = gs.best_estimator['rmse']
print(gs.best_score['rmse'])
print(gs.best_params['rmse'])
cross_validate(algo_grid, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)

# insert parameters from the previous process
algo_svd = SVD(n_factors=160, n_epochs=100, lr_all=0.005, reg_all=0.1)
algo_svd.fit(train_set)
test_pred = algo_svd.test(test_set)

print('SVD: Test Set')
accuracy.rmse(test_pred, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-cdafa2e3ee7d> in <module>()
#      12
#      13 gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=5)
# ---> 14 gs.fit(data)
#      15
#      16 algo_grid = gs.best_estimator['rmse']
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/model_selection/search.py in fit(self, data)
#      88         out = Parallel(n_jobs=self.n_jobs,
#      89                        pre_dispatch=self.pre_dispatch,
# ---> 90                        verbose=self.joblib_verbose)(delayed_list)
#      91
#      92         (test_measures_dicts,
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     981             # remaining jobs.
#     982             self._iterating = False
# --> 983             if self.dispatch_one_batch(iterator):
#     984                 self._iterating = self._original_iterator is not None
#     985
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     823                 return False
#     824             else:
# --> 825                 self._dispatch(tasks)
#     826                 return True
#     827
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     543         # Don't delay the application, to avoid keeping the input
#     544         # arguments in memory
# --> 545         self.results = batch()
#     546
#     547     def get(self):
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/model_selection/validation.py in fit_and_score(algo, trainset, testset, measures, return_train_measures)
#     162
#     163     start_fit = time.time()
# --> 164     algo.fit(trainset)
#     165     fit_time = time.time() - start_fit
#     166     start_test = time.time()
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/prediction_algorithms/matrix_factorization.pyx in surprise.prediction_algorithms.matrix_factorization.SVD.fit()
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/prediction_algorithms/matrix_factorization.pyx in surprise.prediction_algorithms.matrix_factorization.SVD.sgd()
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/trainset.py in all_ratings(self)
#     188         for u, u_ratings in iteritems(self.ur):
#     189             for i, r in u_ratings:
# --> 190                 yield u, i, r
#     191
#     192     def build_testset(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3-2. Matrix Factorization (SVD - HyperParameter Tuning with RandomizedSearchCV)
# ### RandomizedSearchCV.fit 실행시 가동 가능한 모든 코어 가동. GridSearchCV 대비 빨리 돔

# %%
from surprise import SVDpp, SVD, Dataset, accuracy
from surprise.model_selection import train_test_split, cross_validate, RandomizedSearchCV
from surprise.reader import Reader

reader = Reader(line_format='user item rating timestamp', sep='\t')
data = Dataset.load_from_file(file_path, reader=reader)
train_set, test_set = train_test_split(data, test_size=0.2)

param_dists = {'n_factors': [110, 120, 140, 160], 'n_epochs': [90, 100, 110], 
              'lr_all': [0.001, 0.003], 'lr_all': [0.001, 0.003, 0.005, 0.008],
              'reg_all': [0.08, 0.1, 0.15]}

rsc = RandomizedSearchCV(SVD, param_dists, n_iter = 10, measures=['rmse', 'mae'], 
                        cv=5, joblib_verbose = 1000, n_jobs = -1)
rsc.fit(data)

algo_grid = rsc.best_estimator['rmse']
print(rsc.best_score['rmse'])
print(rsc.best_params['rmse'])
cross_validate(algo_grid, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)

# insert parameters from the previous process
algo_svd = SVD(n_factors=160, n_epochs=100, lr_all=0.005, reg_all=0.1)
algo_svd.fit(train_set)
test_pred = algo_svd.test(test_set)

print('SVD: Test Set')
accuracy.rmse(test_pred, verbose=True)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    4.7s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9af336b165ff> in <module>()
#      14 rsc = RandomizedSearchCV(SVD, param_dists, n_iter = 10, measures=['rmse', 'mae', 'fcp'],
#      15                         cv=10, joblib_verbose = 1000, n_jobs = -1)
# ---> 16 rsc.fit(data)
#      17
#      18 algo_grid = rsc.best_estimator['rmse']
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/surprise/model_selection/search.py in fit(self, data)
#      88         out = Parallel(n_jobs=self.n_jobs,
#      89                        pre_dispatch=self.pre_dispatch,
# ---> 90                        verbose=self.joblib_verbose)(delayed_list)
#      91
#      92         (test_measures_dicts,
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     994
#     995             with self._backend.retrieval_context():
# --> 996                 self.retrieve()
#     997             # Make sure that we get a last message telling us we are done
#     998             elapsed_time = time.time() - self._start_time
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     897             try:
#     898                 if getattr(self._backend, 'supports_timeout', False):
# --> 899                     self._output.extend(job.get(timeout=self.timeout))
#     900                 else:
#     901                     self._output.extend(job.get())
#
# ~/dev/lib/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     515         AsyncResults.get from multiprocessing."""
#     516         try:
# --> 517             return future.result(timeout=timeout)
#     518         except LokyTimeoutError:
#     519             raise TimeoutError()
#
# ~/dev/lib/anaconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/dev/lib/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
